# %%
import sys
import os

parent_dir = os.path.dirname(os.getcwd()) 
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

from brainLogin import get_session

session = get_session()

response = session.post("https://api.worldquantbrain.com/authentication")
print(response.status_code)
print(response.json())
# Out:
# 201
# {'user': {'id': 'GY27086'}, 'token': {'expiry': 14400.0}, 'permissions': ['REFERRAL']}

# %%
def get_datafields(
    s,
    searchScope,
    dataset_id: str = '',
    search: str = ''
):
    import pandas as pd
    
    # 从searchScope中提取参数
    instrument_type = searchScope['instrumentType']
    region = searchScope['region']
    delay = searchScope['delay']
    universe = searchScope['universe']
    
    # 根据search参数是否为空构建不同的URL
    if len(search) == 0:
        url_template = "https://api.worldquantbrain.com/data-fields?" +\
            f"&instrumentType={instrument_type}" +\
            f"&region={region}&delay={str(delay)}&universe={universe}&dataset.id={dataset_id}&limit=50" +\
            "&offset={x}"
        print(url_template)
        response = s.get(url_template.format(x=0))
        print(response.status_code)
        print(response.json())
        count = s.get(url_template.format(x=0)).json()['count']
    else:
        url_template = "https://api.worldquantbrain.com/data-fields?" +\
            f"&instrumentType={instrument_type}" +\
            f"&region={region}&delay={str(delay)}&universe={universe}&limit=50" +\
            f"&search={search}" +\
            "&offset={x}"
        count = 100
    
    # 收集所有数据字段
    datafields_list = []
    for x in range(0, count, 50):
        datafields = s.get(url_template.format(x=x))
        datafields_list.append(datafields.json()['results'])
    
    # 展平列表并转换为DataFrame
    datafields_list_flat = [item for sublist in datafields_list for item in sublist]
    datafields_df = pd.DataFrame(datafields_list_flat)
    
    return datafields_df

# %%
searchScope = {'region': 'USA', 'delay': 1, 'universe': 'TOP3000', 'instrumentType': 'EQUITY'}

fundamental6 = get_datafields(s=session,searchScope=searchScope,dataset_id='fundamental6')
# Out:
# https://api.worldquantbrain.com/data-fields?&instrumentType=EQUITY&region=USA&delay=1&universe=TOP3000&dataset.id=fundamental6&limit=50&offset={x}
# 200
# {'count': 886, 'results': [{'id': 'assets', 'description': 'Assets - Total', 'dataset': {'id': 'fundamental6', 'name': 'Company Fundamental Data for Equity'}, 'category': {'id': 'fundamental', 'name': 'Fundamental'}, 'subcategory': {'id': 'fundamental-fundamental-data', 'name': 'Fundamental Data'}, 'region': 'USA', 'delay': 1, 'universe': 'TOP3000', 'type': 'MATRIX', 'coverage': 0.9524, 'userCount': 10540, 'alphaCount': 37058, 'themes': []}, {'id': 'assets_curr', 'description': 'Current Assets - Total', 'dataset': {'id': 'fundamental6', 'name': 'Company Fundamental Data for Equity'}, 'category': {'id': 'fundamental', 'name': 'Fundamental'}, 'subcategory': {'id': 'fundamental-fundamental-data', 'name': 'Fundamental Data'}, 'region': 'USA', 'delay': 1, 'universe': 'TOP3000', 'type': 'MATRIX', 'coverage': 0.7655, 'userCount': 1392, 'alphaCount': 9033, 'themes': []}, {'id': 'bookvalue_ps', 'description': 'Book Value Per Share', 'dataset': {'id': 'fundamental6', 'name': 'Company Fundamental Data for Equity'}, 'category': {'id': 'fundamental', 'name': 'Fundamental'}, 'subcategory': {'id': 'fundamental-fundamental-data', 'name': 'Fundamental Data'}, 'region': 'USA', 'delay': 1, 'universe': 'TOP3000', 'type': 'MATRIX', 'coverage': 0.9754, 'userCount': 1334, 'alphaCount': 7210, 'themes': []}, {'id': 'capex', 'description': 'Capital Expenditures', 'dataset': {'id': 'fundamental6', 'name': 'Company Fundamental Data for Equity'}, 'category': {'id': 'fundamental', 'name': 'Fundamental'}, 'subcategory': {'id': 'fundamental-fundamental-data', 'name': 'Fundamental Data'}, 'region': 'USA', 'delay': 1, 'universe': 'TOP3000', 'type': 'MATRIX', 'coverage': 0.9646, 'userCount': 4972, 'alphaCount': 15362, 'themes': []}, {'id': 'cash', 'description': 'Cash', 'dataset': {'id': 'fundamental6', 'name': 'Company Fundamental Data for Equity'}, 'category': {'id': 'fundamental', 'name': 'Fundamental'}, 'subcategory': {'id': 'fundamental-fundamental-data', 'name': 'Fundamental Data'}, 'region': 'USA', 'delay': 1, 'universe': 'TOP3000', 'type': 'MATRIX', 'coverage': 0.7529, 'userCount': 1327, 'alphaCount': 8915, 'themes': []}, {'id': 'cash_st', 'description': 'Cash and Short-Term Investments', 'dataset': {'id': 'fundamental6', 'name': 'Company Fundamental Data for Equity'}, 'category': {'id': 'fundamental', 'name': 'Fundamental'}, 'subcategory': {'id': 'fundamental-fundamental-data', 'name': 'Fundamental Data'}, 'region': 'USA', 'delay': 1, 'universe': 'TOP3000', 'type': 'MATRIX', 'coverage': 0.9463, 'userCount': 756, 'alphaCount': 6571, 'themes': []}, {'id': 'cashflow', 'description': 'Cashflow (Annual)', 'dataset': {'id': 'fundamental6', 'name': 'Company Fundamental Data for Equity'}, 'category': {'id': 'fundamental', 'name': 'Fundamental'}, 'subcategory': {'id': 'fundamental-fundamental-data', 'name': 'Fundamental Data'}, 'region': 'USA', 'delay': 1, 'universe': 'TOP3000', 'type': 'MATRIX', 'coverage': 0.9251, 'userCount': 1097, 'alphaCount': 6524, 'themes': []}, {'id': 'cashflow_dividends', 'description': 'Cash Dividends (Cash Flow)', 'dataset': {'id': 'fundamental6', 'name': 'Company Fundamental Data for Equity'}, 'category': {'id': 'fundamental', 'name': 'Fundamental'}, 'subcategory': {'id': 'fundamental-fundamental-data', 'name': 'Fundamental Data'}, 'region': 'USA', 'delay': 1, 'universe': 'TOP3000', 'type': 'MATRIX', 'coverage': 0.9564, 'userCount': 1819, 'alphaCount': 4591, 'themes': []}, {'id': 'cashflow_fin', 'description': 'Financing Activities - Net Cash Flow', 'dataset': {'id': 'fundamental6', 'name': 'Company Fundamental Data for Equity'}, 'category': {'id': 'fundamental', 'name': 'Fundamental'}, 'subcategory': {'id': 'fundamental-fundamental-data', 'name': 'Fundamental Data'}, 'region': 'USA', 'delay': 1, 'universe': 'TOP3000', 'type': 'MATRIX', 'coverage': 0.9709, 'userCount': 673, 'alphaCount': 5516, 'themes': []}, {'id': 'cashflow_invst', 'description': 'Investing Activities - Net Cash Flow', 'dataset': {'id': 'fundamental6', 'name': 'Com ...

# %%
fundamental6 = fundamental6[fundamental6['type'] == 'MATRIX']
fundamental6.head()
# Out:
#              id             description  \
# 0        assets          Assets - Total
# 1   assets_curr  Current Assets - Total
# 2  bookvalue_ps    Book Value Per Share
# 3         capex    Capital Expenditures
# 4          cash                    Cash
#
#                                              dataset  \
# 0  {'id': 'fundamental6', 'name': 'Company Fundam...
# 1  {'id': 'fundamental6', 'name': 'Company Fundam...
# 2  {'id': 'fundamental6', 'name': 'Company Fundam...
# 3  {'id': 'fundamental6', 'name': 'Company Fundam...
# 4  {'id': 'fundamental6', 'name': 'Company Fundam...
#
#                                        category  \
# 0  {'id': 'fundamental', 'name': 'Fundamental'}
# 1  {'id': 'fundamental', 'name': 'Fundamental'}
# 2  {'id': 'fundamental', 'name': 'Fundamental'}
# 3  {'id': 'fundamental', 'name': 'Fundamental'}
# 4  {'id': 'fundamental', 'name': 'Fundamental'}
#
#                                          subcategory region  delay universe  \
# 0  {'id': 'fundamental-fundamental-data', 'name':...    USA      1  TOP3000
# 1  {'id': 'fundamental-fundamental-data', 'name':...    USA      1  TOP3000
# 2  {'id': 'fundamental-fundamental-data', 'name':...    USA      1  TOP3000
# 3  {'id': 'fundamental-fundamental-data', 'name':...    USA      1  TOP3000
# 4  {'id': 'fundamental-fundamental-data', 'name':...    USA      1  TOP3000
#
#      type  coverage  userCount  alphaCount themes
# 0  MATRIX    0.9524      10540       37058     []
# 1  MATRIX    0.7655       1392        9033     []
# 2  MATRIX    0.9754       1334        7210     []
# 3  MATRIX    0.9646       4972       15362     []
# 4  MATRIX    0.7529       1327        8915     []

# %%
datafields_list_fundamental6 = fundamental6['id'].values

# %%
# 初始化alpha列表
alpha_list = []

# 遍历fundamental6数据字段列表
for datafield in datafields_list_fundamental6:
    print("正在格加下Alpha表达式与setting对应")
    # 创建alpha表达式：使用group_rank进行处理
    alpha_expression = f'group_rank({datafield}/cap, subindustry)'
    print(alpha_expression)
    
    # 定义模拟设置
    simulation_data = {
        'type': 'REGULAR',
        'settings': {
            'instrumentType': 'EQUITY',
            'region': 'USA',
            'universe': 'TOP3000',
            'delay': 1,
            'decay': 0,
            'neutralization': 'SUBINDUSTRY',
            'truncation': 0.08,
            'pasteurization': 'ON',
            'unitHandling': 'VERIFY',
            'nanHandling': 'ON',
            'language': 'FASTEXPR',
            'visualization': False,
        },
        'regular': alpha_expression
    }
    
    # 将模拟数据添加到alpha列表
    alpha_list.append(simulation_data)

# 打印要模拟的Alpha表达式数量
print(f'there are {len(alpha_list)} Alphas to simulate')
# Out:
# 正在格加下Alpha表达式与setting对应
# group_rank(assets/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(assets_curr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(bookvalue_ps/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(capex/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(cash/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(cash_st/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(cashflow/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(cashflow_dividends/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(cashflow_fin/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(cashflow_invst/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(cashflow_op/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(cogs/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(current_ratio/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(debt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(debt_lt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(debt_st/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(depre_amort/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(ebit/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(ebitda/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(employee/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(enterprise_value/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(eps/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(equity/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_acdo/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_acodo/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_acox/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_acqgdwl/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_acqintan/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_adesinda_curcd/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_aldo/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_am/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_aodo/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_aox/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_aqc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_aqi/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_aqs/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_beta/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_capxv/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_ceql/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_ch/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_ci/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cibegni/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cicurr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cidergl/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cik/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cimii/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_ciother/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cipen/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cisecgl/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_citotal/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_city/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cld2/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cld3/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cld4/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cld5/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptmfmq_actq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptmfmq_atq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptmfmq_ceqq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptmfmq_dlttq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptmfmq_dpq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptmfmq_lctq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptmfmq_oibdpq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptmfmq_opepsq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptmfmq_saleq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_actq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_apq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_atq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_ceqq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_dlttq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_dpq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_epsf12/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_epsfxq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_epsx12/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_lctq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_ltq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_nopiq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_oeps12/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_oiadpq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_oibdpq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_opepsq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_rectq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_req/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptnewqv1300_saleq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cptrank_gvkeymap/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cshpri/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cshr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cshtr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cshtrq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cstkcv/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_cstkcvq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_currencya_curcd/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_currencyqv1300_curcd/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dclo/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dcpstk/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dcvsr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dcvsub/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dcvt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dd/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dd1/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dd1q/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dd2/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dd3/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dd4/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dd5/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dilavx/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dlcch/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dltis/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dlto/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dltp/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dltr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dm/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dn/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_donr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dpvieb/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_drc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_drlt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_ds/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dudd/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dvpa/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dxd2/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dxd3/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dxd4/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_dxd5/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_ein/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_esopct/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_esopnr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_esopr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_esubc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_exre/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_fatb/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_fatc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_fate/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_fatl/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_fatn/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_fato/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_fatp/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_fiao/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_fic/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_fopo/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_fopox/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_fyrc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_ibmii/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_idesindq_curcd/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_idit/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_incorp/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_intan/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_intc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_intpn/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_invfg/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_invo/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_invrm/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_invwip/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_itcb/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_itci/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_ivaco/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_ivaeq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_ivao/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_ivch/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_ivst/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_ivstch/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_lcox/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_lcoxdr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_lifr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_lno/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_loc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_lol2/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_loxdr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_lqpl1/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_lul3/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfma1_aoloch/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfma1_apalch/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfma1_at/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfma1_capx/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfma1_csho/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfma1_dp/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfma1_dpc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfma1_invch/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfma2_oancf/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfma2_opeps/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfma2_recch/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfma2_revt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfma2_txach/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfmq_cheq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfmq_cogsq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfmq_cshprq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfmq_dlcq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfmq_ibcomq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfmq_mibtq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mfmq_piq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mibn/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mibt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mkvalt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mkvaltq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mrc1/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mrc2/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mrc3/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mrc4/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mrc5/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mrct/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_mrcta/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_msa/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_aco/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_acominc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_act/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_ano/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_ao/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_aocidergl/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_aociother/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_aocipen/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_aol2/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_aoloch/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_ap/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_apalch/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_aqpl1/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_at/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_aul3/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_bkvlps/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_caps/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_capx/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_ceq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_ceqt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_che/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_chech/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_cogs/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_cshfd/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_cshi/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_csho/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_cstk/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_dcom/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_dlc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_dltt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_dp/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_dpact/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_dpc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_dv/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_dvc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_dvt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_ebit/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_ebitda/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_emp/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_epsfi/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_epsfx/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_epspi/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_epspx/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_fca/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_fincf/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_gdwl/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_gp/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_ib/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_ibadj/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_ibc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_ibcom/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_icapt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_intano/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_invch/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_invt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_ivncf/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_lco/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_lct/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_lo/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_lse/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa1v1300_lt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_mib/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_mii/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_ni/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_nopi/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_oancf/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_oiadp/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_oibdp/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_opeps/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_optexd/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_pi/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_ppegt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_ppent/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_prsho/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_rdip/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_rdipa/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_rdipd/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_rdipeps/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_re/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_recch/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_rect/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_reuna/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_revt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_sale/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_seq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_seqo/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_spced/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_spceeps/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_spi/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_stkco/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_tstk/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_tstkn/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_txach/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_txdb/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_txditc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_txp/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_txt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_wcap/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_xidoc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_xint/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_xoptd/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_xopteps/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_xrd/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newa2v1300_xsga/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newq_xoptdqp/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newq_xoptepsqp/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newq_xoptqp/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_acomincq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_acoq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_altoq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_ancq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_anoq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_aociderglq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_aociotherq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_aocipenq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_aocisecglq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_aol2q/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_aoq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_aqpl1q/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_aul3q/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_capsq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_chq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_cibegniq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_cicurrq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_ciderglq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_cimiiq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_ciotherq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_cipenq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_ciq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_cisecglq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_citotalq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_cogsq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_csh12q/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_cshfdq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_cshiq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_cshopq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_cshoq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_cshprq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_cstkq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_dcomq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_dilavq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_dlcq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_dpactq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_drcq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_drltq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_epsfiq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_epspiq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_epspxq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_esopnrq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_esoprq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_fcaq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_gdwlq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_glcea12/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_glced12/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_glceeps12/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_ibadj12/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_ibadjq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_ibcomq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_ibmiiq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_ibq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_icaptq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_intanoq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_intanq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_invfgq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_invoq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_invrmq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_invtq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_invwipq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_ivltq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_ivstq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_lcoq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_lltq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_lnoq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_lol2q/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_loq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_loxdrq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_lqpl1q/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_lseq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_ltmibq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_lul3q/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_mibnq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_mibtq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_miiq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_msaq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_oepf12/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_oepsxq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_optfvgrq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_optrfrq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_piq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_pncq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_ppegtq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_ppentq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_prcaq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_prcdq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_prcepsq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_prcraq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_rcpq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_rdipaq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_rdipdq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_rdipepsq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_rdipq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_recdq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_rectaq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_rectoq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_rectrq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_reunaq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_revtq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_seqoq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_seqq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_spcedpq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_spcedq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_spceepsp12/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_spceepspq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_spceepsq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_spcep12/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_spcepd12/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_spcepq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_spceq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_spiq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_stkcoq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_stkcpaq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_teqq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_tfvaq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_tfvceq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_tfvlq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_tstknq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_tstkq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_txdbaq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_txdbq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_txdiq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_txditcq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_txpq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_txtq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_txwq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_wcapq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_xintq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_xoprq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_xoptdq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_xoptepsq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_xoptq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_xrdq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_newqv1300_xsgaq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_niadj/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_nopio/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_np/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_npq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_oprepsx/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optca/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optdr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optdrq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optex/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optfvgr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optgr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optlife/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optlifeq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optosby/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optosey/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optprcby/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optprcca/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optprcex/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optprcey/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optprcgr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optprcwa/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optrfr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optvol/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_optvolq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_pidom/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_pifo/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_pncdq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_pncepsq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_pnrsho/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_ppeveb/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_prcc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_prccq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_prch/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_prchq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_prcl/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_prclq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_prstkc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_pstkc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_pstkl/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_pstkrv/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_rank/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_rea/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_reajo/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_recco/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_recd/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_recta/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_rectr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_siv/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_spce/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_sppe/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_sppiv/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_sstk/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_state/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_stkcpa/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_teq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_tfva/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_tfvce/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_tfvl/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_tlcf/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_tstkc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txbco/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txbcof/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txdba/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txdbca/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txdbcl/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txdbclq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txdc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txdfed/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txdfo/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txdi/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txds/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txfed/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txfo/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txndb/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txndba/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txndbl/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txndbr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txo/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txpd/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txs/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txtubadjust/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txtubbegin/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txtubend/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txtubposdec/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txtubposinc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txtubpospdec/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txtubpospinc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txtubsettle/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txtubsoflimit/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txtubtxtr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txtubxintbs/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txtubxintis/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_txw/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_weburl/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_xacc/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_xaccq/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_xad/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_xintopt/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_xopr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_xpp/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_xpr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_xrent/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(fnd6_zipcode/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(goodwill/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(income/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(income_beforeextra/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(income_tax/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(interest_expense/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(inventory/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(inventory_turnover/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(invested_capital/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(liabilities/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(liabilities_curr/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(operating_expense/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(operating_income/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(ppent/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(pretax_income/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(rd_expense/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(receivable/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(retained_earnings/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(return_assets/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(return_equity/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(revenue/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(sales/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(sales_growth/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(sales_ps/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(sga_expense/cap, subindustry)
# 正在格加下Alpha表达式与setting对应
# group_rank(working_capital/cap, subindustry)
# there are 574 Alphas to simulate

# %%
import json
import os
from time import sleep
from datetime import datetime

def save_simulation_record(alpha_id, datafield, status, filename='simulation_records.json'):
    """保存模拟记录"""
    record = {
        'alpha_id': alpha_id,
        'datafield': datafield,
        'status': status,
        'timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    }
    
    # 加载现有记录
    records = []
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            records = json.load(f)
    
    # 添加新记录
    records.append(record)
    
    # 保存记录
    with open(filename, 'w') as f:
        json.dump(records, f, indent=2)

def get_last_processed_index(filename='simulation_records.json'):
    """获取最后处理的索引"""
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            records = json.load(f)
            return len(records)
    return 0

# 主处理循环
start_index = get_last_processed_index()
print(f"Starting from index {start_index}")

for i, alpha in enumerate(alpha_list[start_index:], start=start_index):
    print(f"Processing alpha {i+1}/{len(alpha_list)}")
    
    try:
        # 发送模拟请求
        sim_resp = session.post(
            'https://api.worldquantbrain.com/simulations',
            json=alpha
        )
        
        try:
            # 获取进度监控URL
            sim_progress_url = sim_resp.headers['Location']
            
            # 循环检查模拟进度
            while True:
                sim_progress_resp = session.get(sim_progress_url)
                retry_after_sec = float(sim_progress_resp.headers.get("Retry-After", 0))
                
                if retry_after_sec == 0:  # simulation done!
                    break
                    
                sleep(retry_after_sec)
                
            # 获取最终模拟结果
            alpha_id = sim_progress_resp.json()["alpha"]
            print(f"Success - Alpha {i+1}: {alpha_id}")
            
            # 保存成功记录
            save_simulation_record(
                alpha_id=alpha_id,
                datafield=alpha['regular'],  # 保存alpha表达式
                status='success'
            )
            
        except Exception as e:
            print(f"Error in simulation {i+1}: {e}")
            # 保存失败记录
            save_simulation_record(
                alpha_id=None,
                datafield=alpha['regular'],
                status=f'error: {str(e)}'
            )
            
    except Exception as e:
        print(f"Failed to start simulation {i+1}: {e}")
        save_simulation_record(
            alpha_id=None,
            datafield=alpha['regular'],
            status=f'failed_to_start: {str(e)}'
        )
# Out:
# Starting from index 0
# Processing alpha 1/574
# Success - Alpha 1: rjnmpb8
# Processing alpha 2/574
# Success - Alpha 2: X7OEGRz
# Processing alpha 3/574
# Success - Alpha 3: qjwZ10Z
# Processing alpha 4/574
# Success - Alpha 4: Q7odk6g
# Processing alpha 5/574
# Success - Alpha 5: V7RogxG
# Processing alpha 6/574
# Success - Alpha 6: kjY5le6
# Processing alpha 7/574
# Success - Alpha 7: mjlk9ox
# Processing alpha 8/574
# Success - Alpha 8: pjpggx3
# Processing alpha 9/574
# Success - Alpha 9: 5l2VRm1
# Processing alpha 10/574
# Success - Alpha 10: oqkeQ6b
# Processing alpha 11/574
# Success - Alpha 11: djPw8px
# Processing alpha 12/574
# Success - Alpha 12: 5l2V7kn
# Processing alpha 13/574
# Success - Alpha 13: N72oqeo
# Processing alpha 14/574
# Success - Alpha 14: W7xmdXx
# Processing alpha 15/574
# Success - Alpha 15: 2l2kRxY
# Processing alpha 16/574
# Success - Alpha 16: 7j2Vx8L
# Processing alpha 17/574
# Success - Alpha 17: M72Akln
# Processing alpha 18/574
# Success - Alpha 18: El2AkLr
# Processing alpha 19/574
# Success - Alpha 19: 6l2bEYE
# Processing alpha 20/574
# Success - Alpha 20: 6l2bwzO
# Processing alpha 21/574
# Success - Alpha 21: J72LObO
# Processing alpha 22/574
# Success - Alpha 22: ezWJxml
# Processing alpha 23/574
# Success - Alpha 23: vjoVNRA
# Processing alpha 24/574
# Success - Alpha 24: n7Xb71z
# Processing alpha 25/574
# Success - Alpha 25: M72A7e9
# Processing alpha 26/574
# Success - Alpha 26: 1w25xZz
# Processing alpha 27/574
# Success - Alpha 27: pjpgRr6
# Processing alpha 28/574
# Success - Alpha 28: pjpgRvg
# Processing alpha 29/574
# Success - Alpha 29: R7vL6ad
# Processing alpha 30/574
# Success - Alpha 30: 1w25jzK
# Processing alpha 31/574
# Success - Alpha 31: N72oNwo
# Processing alpha 32/574
# Success - Alpha 32: Al2dxRd
# Processing alpha 33/574
# Success - Alpha 33: ljNZaKO
# Processing alpha 34/574
# Success - Alpha 34: Y79dl5w
# Processing alpha 35/574
# Success - Alpha 35: 0waWx76
# Processing alpha 36/574
# Success - Alpha 36: 8l2qEK7
# Processing alpha 37/574
# Success - Alpha 37: P7AEzXK
# Processing alpha 38/574
# Success - Alpha 38: 5l2Ve0X
# Processing alpha 39/574
# Success - Alpha 39: 5l2Vemn
# Processing alpha 40/574
# Success - Alpha 40: oqkeZW5
# Processing alpha 41/574
# Success - Alpha 41: R7vLvZz
# Processing alpha 42/574
# Success - Alpha 42: vjoVb93
# Processing alpha 43/574
# Success - Alpha 43: pjpgk2X
# Processing alpha 44/574
# Success - Alpha 44: 1w25ANJ
# Processing alpha 45/574
# Success - Alpha 45: kjY5p3k
# Processing alpha 46/574
# Success - Alpha 46: xjEaLwW
# Processing alpha 47/574
# Success - Alpha 47: xjEaLVN
# Processing alpha 48/574
# Success - Alpha 48: qjwZQlv
# Processing alpha 49/574
# Success - Alpha 49: vjo0KwA
# Processing alpha 50/574
# Success - Alpha 50: Z71ZR1Y
# Processing alpha 51/574
# Success - Alpha 51: W7xkj2O
# Processing alpha 52/574
# Success - Alpha 52: mjlOwvW
# Processing alpha 53/574
# Success - Alpha 53: ljNxdMO
# Processing alpha 54/574
# Success - Alpha 54: Z71Z53Z
# Processing alpha 55/574
# Success - Alpha 55: a7gJZ7O
# Processing alpha 56/574
# Success - Alpha 56: 3l2dZbO
# Processing alpha 57/574
# Success - Alpha 57: 7j2OEjL
# Processing alpha 58/574
# Success - Alpha 58: L72eJge
# Processing alpha 59/574
# Success - Alpha 59: 3l2dWZe
# Processing alpha 60/574
# Success - Alpha 60: djPqqXw
# Processing alpha 61/574
# Success - Alpha 61: gj0v7zM
# Processing alpha 62/574
# Success - Alpha 62: R7vXZ6o
# Processing alpha 63/574
# Success - Alpha 63: M72wqdM
# Processing alpha 64/574
# Success - Alpha 64: xjEMzVw
# Processing alpha 65/574
# Success - Alpha 65: ezWAqEd
# Processing alpha 66/574
# Success - Alpha 66: El23gGK
# Processing alpha 67/574
# Success - Alpha 67: wjv65n2
# Processing alpha 68/574
# Success - Alpha 68: X7Oq1Lb
# Processing alpha 69/574
# Success - Alpha 69: Gl7VoV3
# Processing alpha 70/574
# Success - Alpha 70: 5l2RwxJ
# Processing alpha 71/574
# Success - Alpha 71: Al26wEY
# Processing alpha 72/574
# Success - Alpha 72: Y79Z0kW
# Processing alpha 73/574
# Success - Alpha 73: jjMLr1W
# Processing alpha 74/574
# Success - Alpha 74: a7gJ1XR
# Processing alpha 75/574
# Success - Alpha 75: 9X2oXj9
# Processing alpha 76/574
# Success - Alpha 76: Q7oe3XQ
# Processing alpha 77/574
# Success - Alpha 77: ezWA95J
# Processing alpha 78/574
# Success - Alpha 78: zkLa8J1
# Processing alpha 79/574
# Success - Alpha 79: pjp05Ao
# Processing alpha 80/574
# Success - Alpha 80: 8l2ARez
# Processing alpha 81/574
# Success - Alpha 81: gj0vao0
# Processing alpha 82/574
# Success - Alpha 82: 9X2oGkV
# Processing alpha 83/574
# Success - Alpha 83: bjKpJM6
# Processing alpha 84/574
# Success - Alpha 84: R7vXlJ1
# Processing alpha 85/574
# Success - Alpha 85: Y79ZEaJ
# Processing alpha 86/574
# Success - Alpha 86: O72eVmg
# Processing alpha 87/574
# Success - Alpha 87: xjEMWLq
# Processing alpha 88/574
# Success - Alpha 88: R7vXP8j
# Processing alpha 89/574
# Success - Alpha 89: xjEMEOq
# Processing alpha 90/574
# Success - Alpha 90: jjMLK15
# Processing alpha 91/574
# Success - Alpha 91: W7xkrKj
# Processing alpha 92/574
# Success - Alpha 92: 7j2O5zQ
# Processing alpha 93/574
# Error in simulation 93: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Processing alpha 94/574
# Success - Alpha 94: ljNxoQN
# Processing alpha 95/574
# Success - Alpha 95: Gl7VZ5Q
# Processing alpha 96/574
# Success - Alpha 96: 8l2g86W
# Processing alpha 97/574
# Success - Alpha 97: W7xK1Ad
# Processing alpha 98/574
# Success - Alpha 98: wjvXqzd
# Processing alpha 99/574
# Success - Alpha 99: 5l2NbR6
# Processing alpha 100/574
# Success - Alpha 100: gj07Ozm
# Processing alpha 101/574
# Success - Alpha 101: bjK752M
# Processing alpha 102/574
# Success - Alpha 102: M729oNa
# Processing alpha 103/574
# Success - Alpha 103: oqkQemm
# Processing alpha 104/574
# Success - Alpha 104: O72Kvz1
# Processing alpha 105/574
# Success - Alpha 105: qjweerV
# Processing alpha 106/574
# Success - Alpha 106: ljNJ6o7
# Processing alpha 107/574
# Success - Alpha 107: V7RKqeM
# Processing alpha 108/574
# Success - Alpha 108: a7gXP6w
# Processing alpha 109/574
# Success - Alpha 109: K72xwlE
# Processing alpha 110/574
# Success - Alpha 110: Gl7EMGG
# Processing alpha 111/574
# Success - Alpha 111: R7v0NXe
# Processing alpha 112/574
# Success - Alpha 112: 1w26JqR
# Processing alpha 113/574
# Success - Alpha 113: rjnQWAE
# Processing alpha 114/574
# Success - Alpha 114: M729xra
# Processing alpha 115/574
# Success - Alpha 115: mjle85E
# Processing alpha 116/574
# Success - Alpha 116: 6l2g9qp
# Processing alpha 117/574
# Success - Alpha 117: Q7om91p
# Processing alpha 118/574
# Success - Alpha 118: 8l2gp8z
# Processing alpha 119/574
# Success - Alpha 119: oqkQNbm
# Processing alpha 120/574
# Success - Alpha 120: El2ol2m
# Processing alpha 121/574
# Success - Alpha 121: vjoakdA
# Processing alpha 122/574
# Success - Alpha 122: zkLX86O
# Processing alpha 123/574
# Success - Alpha 123: bjK7bzK
# Processing alpha 124/574
# Success - Alpha 124: R7v06za
# Processing alpha 125/574
# Success - Alpha 125: xjEX1lw
# Processing alpha 126/574
# Success - Alpha 126: J72R8VO
# Processing alpha 127/574
# Success - Alpha 127: ezWeaNg
# Processing alpha 128/574
# Success - Alpha 128: 9X2gGbe
# Processing alpha 129/574
# Success - Alpha 129: 8l2gVza
# Processing alpha 130/574
# Success - Alpha 130: Y79XEGq
# Processing alpha 131/574
# Success - Alpha 131: 1w26l2m
# Processing alpha 132/574
# Success - Alpha 132: kjYeGjg
# Processing alpha 133/574
# Success - Alpha 133: xjEXW8q
# Processing alpha 134/574
# Success - Alpha 134: n7XwQ5q
# Processing alpha 135/574
# Success - Alpha 135: Z71kNmj
# Processing alpha 136/574
# Success - Alpha 136: V7RKRwM
# Processing alpha 137/574
# Success - Alpha 137: Al2q8aR
# Processing alpha 138/574
# Success - Alpha 138: Al2qXaw
# Processing alpha 139/574
# Success - Alpha 139: 6l2gW75
# Processing alpha 140/574
# Success - Alpha 140: 5l2Nmr6
# Processing alpha 141/574
# Success - Alpha 141: 5l2NXQX
# Processing alpha 142/574
# Success - Alpha 142: gj07n7O
# Processing alpha 143/574
# Success - Alpha 143: 1w26r06
# Processing alpha 144/574
# Success - Alpha 144: J720V0W
# Processing alpha 145/574
# Success - Alpha 145: djP8kJx
# Processing alpha 146/574
# Success - Alpha 146: n7Xk9gl
# Processing alpha 147/574
# Success - Alpha 147: vjonq0a
# Processing alpha 148/574
# Success - Alpha 148: oqkw5Yl
# Processing alpha 149/574
# Success - Alpha 149: Y79wGrM
# Processing alpha 150/574
# Success - Alpha 150: Al2JM5W
# Processing alpha 151/574
# Success - Alpha 151: O72warY
# Processing alpha 152/574
# Success - Alpha 152: 2l2qkRw
# Processing alpha 153/574
# Success - Alpha 153: xjEwMzq
# Processing alpha 154/574
# Success - Alpha 154: 8l2kgxV
# Processing alpha 155/574
# Success - Alpha 155: rjn66od
# Processing alpha 156/574
# Success - Alpha 156: pjpJoAv
# Processing alpha 157/574
# Success - Alpha 157: vjonzkG
# Processing alpha 158/574
# Success - Alpha 158: K72Ywzg
# Processing alpha 159/574
# Success - Alpha 159: O72wbnp
# Processing alpha 160/574
# Success - Alpha 160: 2l2qvEN
# Processing alpha 161/574
# Success - Alpha 161: V7RwOK8
# Processing alpha 162/574
# Success - Alpha 162: wjvwL3Y
# Processing alpha 163/574
# Success - Alpha 163: rjn6Wbd
# Processing alpha 164/574
# Success - Alpha 164: ljN60oe
# Processing alpha 165/574
# Success - Alpha 165: oqkwKqn
# Processing alpha 166/574
# Success - Alpha 166: 5l27O7J
# Processing alpha 167/574
# Success - Alpha 167: N72WRqX
# Processing alpha 168/574
# Success - Alpha 168: djP8Zpv
# Processing alpha 169/574
# Success - Alpha 169: V7RwGa5
# Processing alpha 170/574
# Success - Alpha 170: 7j2qjbb
# Processing alpha 171/574
# Success - Alpha 171: M72l76z
# Processing alpha 172/574
# Success - Alpha 172: kjYkVLK
# Processing alpha 173/574
# Success - Alpha 173: N72Wamp
# Processing alpha 174/574
# Success - Alpha 174: O72wN61
# Processing alpha 175/574
# Success - Alpha 175: 9X2PWR2
# Processing alpha 176/574
# Success - Alpha 176: qjwkE9V
# Processing alpha 177/574
# Success - Alpha 177: pjpJvG6
# Processing alpha 178/574
# Success - Alpha 178: vjon1vb
# Processing alpha 179/574
# Success - Alpha 179: 3l2Y0oZ
# Processing alpha 180/574
# Success - Alpha 180: ezW81K6
# Processing alpha 181/574
# Success - Alpha 181: 1w2VOkJ
# Processing alpha 182/574
# Success - Alpha 182: ljN6Ev8
# Processing alpha 183/574
# Success - Alpha 183: djP83w2
# Processing alpha 184/574
# Success - Alpha 184: L72bmmL
# Processing alpha 185/574
# Success - Alpha 185: xjEw58b
# Processing alpha 186/574
# Success - Alpha 186: mjl2lk9
# Processing alpha 187/574
# Success - Alpha 187: X7Owx25
# Processing alpha 188/574
# Success - Alpha 188: V7RwLr5
# Processing alpha 189/574
# Success - Alpha 189: qjwk21P
# Processing alpha 190/574
# Success - Alpha 190: n7XkGvw
# Processing alpha 191/574
# Success - Alpha 191: 3l2YKnX
# Processing alpha 192/574
# Success - Alpha 192: 3l2YNqZ
# Processing alpha 193/574
# Success - Alpha 193: djP8GYY
# Processing alpha 194/574
# Success - Alpha 194: 3l2Y8LZ
# Processing alpha 195/574
# Success - Alpha 195: djPg2eE
# Processing alpha 196/574
# Success - Alpha 196: vjoxKAG
# Processing alpha 197/574
# Success - Alpha 197: M72qPxk
# Processing alpha 198/574
# Success - Alpha 198: O72q0LR
# Processing alpha 199/574
# Success - Alpha 199: bjKVGOm
# Processing alpha 200/574
# Success - Alpha 200: 5l23bEN
# Processing alpha 201/574
# Success - Alpha 201: rjnEgQ1
# Processing alpha 202/574
# Success - Alpha 202: 1w21Qqk
# Processing alpha 203/574
# Success - Alpha 203: gj0wEGK
# Processing alpha 204/574
# Success - Alpha 204: djPgLAJ
# Processing alpha 205/574
# Success - Alpha 205: xjE9gEW
# Processing alpha 206/574
# Success - Alpha 206: R7vqLld
# Processing alpha 207/574
# Success - Alpha 207: M72qwbk
# Processing alpha 208/574
# Success - Alpha 208: O72qKG1
# Processing alpha 209/574
# Success - Alpha 209: 1w21VvX
# Processing alpha 210/574
# Success - Alpha 210: djPggmw
# Processing alpha 211/574
# Success - Alpha 211: rjnEL1m
# Processing alpha 212/574
# Success - Alpha 212: n7XYond
# Processing alpha 213/574
# Success - Alpha 213: a7gMlmO
# Processing alpha 214/574
# Success - Alpha 214: Al2Ygag
# Processing alpha 215/574
# Success - Alpha 215: wjvO58Q
# Processing alpha 216/574
# Success - Alpha 216: Y79nNMJ
# Processing alpha 217/574
# Success - Alpha 217: pjpo88q
# Processing alpha 218/574
# Success - Alpha 218: 6l23EvJ
# Processing alpha 219/574
# Success - Alpha 219: oqkAYdl
# Processing alpha 220/574
# Success - Alpha 220: xjE9kOm
# Processing alpha 221/574
# Success - Alpha 221: 0wa9Ew8
# Processing alpha 222/574
# Success - Alpha 222: n7XY86E
# Processing alpha 223/574
# Success - Alpha 223: Q7oqGEw
# Processing alpha 224/574
# Success - Alpha 224: W7xn7Qj
# Processing alpha 225/574
# Success - Alpha 225: K72q72z
# Processing alpha 226/574
# Success - Alpha 226: J72YxvO
# Processing alpha 227/574
# Success - Alpha 227: mjlJmw6
# Processing alpha 228/574
# Success - Alpha 228: K72qrQ8
# Processing alpha 229/574
# Success - Alpha 229: K72qmvx
# Processing alpha 230/574
# Success - Alpha 230: ezWg5VE
# Processing alpha 231/574
# Success - Alpha 231: El2YmWm
# Processing alpha 232/574
# Success - Alpha 232: 7j20G3Z
# Processing alpha 233/574
# Success - Alpha 233: Gl7YXlx
# Processing alpha 234/574
# Success - Alpha 234: 5l23ANn
# Processing alpha 235/574
# Success - Alpha 235: zkLQGpO
# Processing alpha 236/574
# Success - Alpha 236: pjpoGkq
# Processing alpha 237/574
# Success - Alpha 237: Al2Ym3Y
# Processing alpha 238/574
# Success - Alpha 238: xjE9W5b
# Processing alpha 239/574
# Success - Alpha 239: zkLQeoE
# Processing alpha 240/574
# Success - Alpha 240: gj0wL20
# Processing alpha 241/574
# Success - Alpha 241: R7vqoXn
# Processing alpha 242/574
# Success - Alpha 242: Al2Y55Y
# Processing alpha 243/574
# Success - Alpha 243: vjoxXew
# Processing alpha 244/574
# Success - Alpha 244: M72qv7n
# Processing alpha 245/574
# Success - Alpha 245: L72qvJM
# Processing alpha 246/574
# Success - Alpha 246: xjE9ZAm
# Processing alpha 247/574
# Success - Alpha 247: 0wa91EK
# Processing alpha 248/574
# Success - Alpha 248: mjlAPkx
# Processing alpha 249/574
# Success - Alpha 249: 2l2R16N
# Processing alpha 250/574
# Success - Alpha 250: 3l2xqzg
# Processing alpha 251/574
# Success - Alpha 251: W7xd11Z
# Processing alpha 252/574
# Success - Alpha 252: bjKMG6M
# Processing alpha 253/574
# Success - Alpha 253: N7260kw
# Processing alpha 254/574
# Success - Alpha 254: 0wadq2p
# Processing alpha 255/574
# Success - Alpha 255: M72XRRo
# Processing alpha 256/574
# Success - Alpha 256: ljN2b6x
# Processing alpha 257/574
# Success - Alpha 257: El2bX2P
# Processing alpha 258/574
# Success - Alpha 258: 6l21OoL
# Processing alpha 259/574
# Success - Alpha 259: rjnLmAE
# Processing alpha 260/574
# Success - Alpha 260: X7OLqLl
# Processing alpha 261/574
# Success - Alpha 261: Z71xZMQ
# Processing alpha 262/574
# Success - Alpha 262: kjYXej6
# Processing alpha 263/574
# Success - Alpha 263: djPm8gX
# Processing alpha 264/574
# Success - Alpha 264: gj0KqVe
# Processing alpha 265/574
# Success - Alpha 265: N726qLq
# Processing alpha 266/574
# Success - Alpha 266: L72669n
# Processing alpha 267/574
# Success - Alpha 267: W7xdX3o
# Processing alpha 268/574
# Success - Alpha 268: V7REYlb
# Processing alpha 269/574
# Success - Alpha 269: P7A6vpw
# Processing alpha 270/574
# Success - Alpha 270: Al2bwqw
# Processing alpha 271/574
# Success - Alpha 271: 2l2RLa8
# Processing alpha 272/574
# Success - Alpha 272: V7RE3Mb
# Processing alpha 273/574
# Success - Alpha 273: P7A6Gv7
# Processing alpha 274/574
# Success - Alpha 274: Gl76lnP
# Processing alpha 275/574
# Success - Alpha 275: X7OLW25
# Processing alpha 276/574
# Success - Alpha 276: 7j2Q695
# Processing alpha 277/574
# Success - Alpha 277: 1w2LZl6
# Processing alpha 278/574
# Success - Alpha 278: X7OLRbm
# Processing alpha 279/574
# Success - Alpha 279: Y79m1GR
# Processing alpha 280/574
# Success - Alpha 280: xjEQvdb
# Processing alpha 281/574
# Success - Alpha 281: zkLjAZO
# Processing alpha 282/574
# Success - Alpha 282: K726vPl
# Processing alpha 283/574
# Success - Alpha 283: wjv1326
# Processing alpha 284/574
# Success - Alpha 284: Y79mEQM
# Processing alpha 285/574
# Success - Alpha 285: 0wadge8
# Processing alpha 286/574
# Success - Alpha 286: 0wad6Kr
# Processing alpha 287/574
# Success - Alpha 287: X7OLMq1
# Processing alpha 288/574
# Success - Alpha 288: xjEQ52p
# Processing alpha 289/574
# Success - Alpha 289: xjEQpeN
# Processing alpha 290/574
# Success - Alpha 290: X7OLAM8
# Processing alpha 291/574
# Success - Alpha 291: 6l216jY
# Processing alpha 292/574
# Success - Alpha 292: Q7ojxrQ
# Processing alpha 293/574
# Success - Alpha 293: P7A6VNJ
# Processing alpha 294/574
# Success - Alpha 294: 6l21k6K
# Processing alpha 295/574
# Success - Alpha 295: ezWKXzl
# Processing alpha 296/574
# Success - Alpha 296: 0waQbQq
# Processing alpha 297/574
# Success - Alpha 297: Al2aRXE
# Processing alpha 298/574
# Success - Alpha 298: El2a5Qm
# Processing alpha 299/574
# Success - Alpha 299: jjMwzlZ
# Processing alpha 300/574
# Success - Alpha 300: oqkz8a5
# Processing alpha 301/574
# Success - Alpha 301: jjMwv2j
# Processing alpha 302/574
# Success - Alpha 302: qjwz8WE
# Processing alpha 303/574
# Success - Alpha 303: djP7XZY
# Processing alpha 304/574
# Success - Alpha 304: djP7VL2
# Processing alpha 305/574
# Success - Alpha 305: K728jXp
# Processing alpha 306/574
# Success - Alpha 306: Q7olL8W
# Processing alpha 307/574
# Success - Alpha 307: L72XJEM
# Processing alpha 308/574
# Success - Alpha 308: Al2adKR
# Processing alpha 309/574
# Success - Alpha 309: mjlzOPx
# Processing alpha 310/574
# Success - Alpha 310: ezW2Avl
# Processing alpha 311/574
# Success - Alpha 311: jjMwN6E
# Processing alpha 312/574
# Success - Alpha 312: xjEzwnm
# Processing alpha 313/574
# Success - Alpha 313: Q7olqMW
# Processing alpha 314/574
# Success - Alpha 314: pjpzEwV
# Processing alpha 315/574
# Success - Alpha 315: L72X6G1
# Processing alpha 316/574
# Success - Alpha 316: 7j2XX9Z
# Processing alpha 317/574
# Success - Alpha 317: pjpzzWX
# Processing alpha 318/574
# Success - Alpha 318: Y79kWQJ
# Processing alpha 319/574
# Success - Alpha 319: 1w2makW
# Processing alpha 320/574
# Success - Alpha 320: Q7ol20r
# Processing alpha 321/574
# Success - Alpha 321: 0waQA7r
# Processing alpha 322/574
# Success - Alpha 322: 9X269ed
# Processing alpha 323/574
# Success - Alpha 323: W7xX9bP
# Processing alpha 324/574
# Success - Alpha 324: mjlzXw2
# Processing alpha 325/574
# Success - Alpha 325: O72m9dY
# Processing alpha 326/574
# Success - Alpha 326: n7Xzg33
# Processing alpha 327/574
# Success - Alpha 327: R7va8jj
# Processing alpha 328/574
# Success - Alpha 328: N72jrEo
# Processing alpha 329/574
# Success - Alpha 329: 9X267pq
# Processing alpha 330/574
# Success - Alpha 330: O72mGbb
# Processing alpha 331/574
# Success - Alpha 331: xjEzjPN
# Processing alpha 332/574
# Success - Alpha 332: K7287Wl
# Processing alpha 333/574
# Success - Alpha 333: Q7ol33X
# Processing alpha 334/574
# Success - Alpha 334: pjpzR2x
# Processing alpha 335/574
# Success - Alpha 335: L72XZda
# Processing alpha 336/574
# Success - Alpha 336: qjwzErZ
# Processing alpha 337/574
# Success - Alpha 337: 7j2XoYO
# Processing alpha 338/574
# Success - Alpha 338: gj0Pezm
# Processing alpha 339/574
# Success - Alpha 339: n7XzvGd
# Processing alpha 340/574
# Success - Alpha 340: qjwz7Ej
# Processing alpha 341/574
# Success - Alpha 341: Q7olWVr
# Processing alpha 342/574
# Success - Alpha 342: vjozZ8w
# Processing alpha 343/574
# Success - Alpha 343: Gl78XG0
# Processing alpha 344/574
# Success - Alpha 344: jjMwPQO
# Processing alpha 345/574
# Success - Alpha 345: J72XzwO
# Processing alpha 346/574
# Success - Alpha 346: jjMwxQZ
# Processing alpha 347/574
# Success - Alpha 347: N72j8GX
# Processing alpha 348/574
# Success - Alpha 348: L72X22M
# Processing alpha 349/574
# Success - Alpha 349: Z71l9gd
# Processing alpha 350/574
# Success - Alpha 350: rjnzMQm
# Processing alpha 351/574
# Success - Alpha 351: Z71lvX8
# Processing alpha 352/574
# Success - Alpha 352: R7vaxra
# Processing alpha 353/574
# Success - Alpha 353: pjpz2Jo
# Processing alpha 354/574
# Success - Alpha 354: K728138
# Processing alpha 355/574
# Success - Alpha 355: mjlzv1K
# Processing alpha 356/574
# Success - Alpha 356: 6l2q5Kp
# Processing alpha 357/574
# Success - Alpha 357: 1w2nq1R
# Processing alpha 358/574
# Success - Alpha 358: Q7o51WM
# Processing alpha 359/574
# Success - Alpha 359: qjwmM0E
# Processing alpha 360/574
# Success - Alpha 360: K72wlw1
# Processing alpha 361/574
# Success - Alpha 361: V7RYVow
# Processing alpha 362/574
# Success - Alpha 362: X7OYGx5
# Processing alpha 363/574
# Success - Alpha 363: 5l2qb6M
# Processing alpha 364/574
# Success - Alpha 364: jjMdEKo
# Processing alpha 365/574
# Success - Alpha 365: ljNROjO
# Processing alpha 366/574
# Success - Alpha 366: Gl73pj3
# Processing alpha 367/574
# Success - Alpha 367: 3l2nWk0
# Processing alpha 368/574
# Success - Alpha 368: 9X2AoXe
# Processing alpha 369/574
# Success - Alpha 369: Al2Oqal
# Processing alpha 370/574
# Success - Alpha 370: Gl730NG
# Processing alpha 371/574
# Success - Alpha 371: djPlgzY
# Processing alpha 372/574
# Success - Alpha 372: 3l2nxx0
# Processing alpha 373/574
# Success - Alpha 373: vjoJ9P3
# Processing alpha 374/574
# Success - Alpha 374: djPl7Wj
# Processing alpha 375/574
# Success - Alpha 375: L72llXa
# Processing alpha 376/574
# Success - Alpha 376: ezWqdlp
# Processing alpha 377/574
# Success - Alpha 377: mjlxr76
# Processing alpha 378/574
# Success - Alpha 378: 6l2YRaY
# Processing alpha 379/574
# Success - Alpha 379: 5l2qMzX
# Processing alpha 380/574
# Success - Alpha 380: 6l2YE3E
# Processing alpha 381/574
# Success - Alpha 381: Q7o5aM5
# Processing alpha 382/574
# Success - Alpha 382: kjYL3Y6
# Processing alpha 383/574
# Success - Alpha 383: jjMd0rj
# Processing alpha 384/574
# Success - Alpha 384: O725xvp
# Processing alpha 385/574
# Success - Alpha 385: 2l2nN25
# Processing alpha 386/574
# Success - Alpha 386: Al2OG0Q
# Processing alpha 387/574
# Success - Alpha 387: 6l2YlwG
# Processing alpha 388/574
# Success - Alpha 388: 0waKR0K
# Processing alpha 389/574
# Success - Alpha 389: mjlxgnW
# Processing alpha 390/574
# Success - Alpha 390: El2rpm1
# Processing alpha 391/574
# Success - Alpha 391: 5l2qgL6
# Processing alpha 392/574
# Success - Alpha 392: 9X2AEZK
# Processing alpha 393/574
# Success - Alpha 393: 1w2nj3M
# Processing alpha 394/574
# Success - Alpha 394: M7256Ao
# Processing alpha 395/574
# Success - Alpha 395: oqk9axb
# Processing alpha 396/574
# Success - Alpha 396: 2l2n91Y
# Processing alpha 397/574
# Success - Alpha 397: 1w2nlvX
# Processing alpha 398/574
# Success - Alpha 398: 8l2KJ9v
# Processing alpha 399/574
# Success - Alpha 399: N725z2L
# Processing alpha 400/574
# Success - Alpha 400: vjoJ61v
# Processing alpha 401/574
# Success - Alpha 401: Y79WYGv
# Processing alpha 402/574
# Success - Alpha 402: vjoJPoG
# Processing alpha 403/574
# Success - Alpha 403: pjp1eNv
# Processing alpha 404/574
# Success - Alpha 404: n7XOGx3
# Processing alpha 405/574
# Success - Alpha 405: Y79W3Rq
# Processing alpha 406/574
# Success - Alpha 406: 9X2AeO9
# Processing alpha 407/574
# Success - Alpha 407: 5l2qXwX
# Processing alpha 408/574
# Success - Alpha 408: K72wWak
# Processing alpha 409/574
# Success - Alpha 409: Al2OoEl
# Processing alpha 410/574
# Success - Alpha 410: O72b1xq
# Processing alpha 411/574
# Success - Alpha 411: xjEPA0N
# Processing alpha 412/574
# Success - Alpha 412: R7v2Roa
# Processing alpha 413/574
# Success - Alpha 413: Al2gjrW
# Processing alpha 414/574
# Success - Alpha 414: a7gA6d1
# Processing alpha 415/574
# Success - Alpha 415: wjvnmJp
# Processing alpha 416/574
# Success - Alpha 416: jjM9EMO
# Processing alpha 417/574
# Success - Alpha 417: 5l2a0Xk
# Processing alpha 418/574
# Success - Alpha 418: 9X2aLWr
# Processing alpha 419/574
# Success - Alpha 419: ezWdRdM
# Processing alpha 420/574
# Success - Alpha 420: n7XZVXd
# Processing alpha 421/574
# Success - Alpha 421: oqk3eo2
# Processing alpha 422/574
# Success - Alpha 422: n7XZ0Va
# Processing alpha 423/574
# Success - Alpha 423: N72gk9L
# Processing alpha 424/574
# Success - Alpha 424: K72XYPj
# Processing alpha 425/574
# Error in simulation 425: 'alpha'
# Processing alpha 426/574
# Success - Alpha 426: J72gY5E
# Processing alpha 427/574
# Success - Alpha 427: oqk3Ax5
# Processing alpha 428/574
# Success - Alpha 428: vjoe9AQ
# Processing alpha 429/574
# Success - Alpha 429: J72gXbj
# Processing alpha 430/574
# Success - Alpha 430: gj0RmRe
# Processing alpha 431/574
# Success - Alpha 431: jjM9159
# Processing alpha 432/574
# Success - Alpha 432: El2gkmK
# Processing alpha 433/574
# Success - Alpha 433: 5l2avwJ
# Processing alpha 434/574
# Success - Alpha 434: wjvnlK5
# Processing alpha 435/574
# Success - Alpha 435: El2gegG
# Processing alpha 436/574
# Success - Alpha 436: V7R2GEA
# Processing alpha 437/574
# Success - Alpha 437: 7j2azl8
# Processing alpha 438/574
# Success - Alpha 438: ezWdzag
# Processing alpha 439/574
# Success - Alpha 439: 1w2axwX
# Processing alpha 440/574
# Success - Alpha 440: ljNQvWx
# Processing alpha 441/574
# Success - Alpha 441: djPE1qw
# Processing alpha 442/574
# Success - Alpha 442: Q7o20qQ
# Processing alpha 443/574
# Success - Alpha 443: jjM9VzE
# Processing alpha 444/574
# Success - Alpha 444: 3l2a1ZX
# Processing alpha 445/574
# Success - Alpha 445: 9X2a8lo
# Processing alpha 446/574
# Success - Alpha 446: oqk3G22
# Processing alpha 447/574
# Success - Alpha 447: ljNQGE8
# Processing alpha 448/574
# Success - Alpha 448: M72KZ8L
# Processing alpha 449/574
# Success - Alpha 449: 3l2a5vg
# Processing alpha 450/574
# Success - Alpha 450: 6l2aNwY
# Processing alpha 451/574
# Success - Alpha 451: N72g25o
# Processing alpha 452/574
# Success - Alpha 452: 0waeL3v
# Processing alpha 453/574
# Success - Alpha 453: rjnJMXd
# Processing alpha 454/574
# Success - Alpha 454: djPErMg
# Processing alpha 455/574
# Success - Alpha 455: qjwP2aj
# Processing alpha 456/574
# Success - Alpha 456: Q7o2x0W
# Processing alpha 457/574
# Success - Alpha 457: V7R2WOb
# Processing alpha 458/574
# Success - Alpha 458: Y792RKl
# Processing alpha 459/574
# Success - Alpha 459: Y79NjLM
# Processing alpha 460/574
# Success - Alpha 460: wjv58Qp
# Processing alpha 461/574
# Success - Alpha 461: J72njbA
# Processing alpha 462/574
# Success - Alpha 462: N72nxqg
# Processing alpha 463/574
# Success - Alpha 463: Z71j6A3
# Processing alpha 464/574
# Success - Alpha 464: n7XnJ6z
# Processing alpha 465/574
# Success - Alpha 465: oqkn5lE
# Processing alpha 466/574
# Success - Alpha 466: K72njEE
# Processing alpha 467/574
# Success - Alpha 467: vjo5gw3
# Processing alpha 468/574
# Success - Alpha 468: jjMnmGo
# Processing alpha 469/574
# Success - Alpha 469: kjYn53l
# Processing alpha 470/574
# Success - Alpha 470: Y79NZ0v
# Processing alpha 471/574
# Success - Alpha 471: Q7onmew
# Processing alpha 472/574
# Success - Alpha 472: Z71jkzY
# Processing alpha 473/574
# Success - Alpha 473: wjv5wox
# Processing alpha 474/574
# Success - Alpha 474: Z71jxg0
# Processing alpha 475/574
# Success - Alpha 475: Z71jll1
# Processing alpha 476/574
# Success - Alpha 476: R7vNkM1
# Processing alpha 477/574
# Success - Alpha 477: zkL5PjE
# Processing alpha 478/574
# Success - Alpha 478: X7Okka0
# Processing alpha 479/574
# Success - Alpha 479: 6l2RzkP
# Processing alpha 480/574
# Success - Alpha 480: 3l2E7dN
# Processing alpha 481/574
# Success - Alpha 481: ezWnOjl
# Processing alpha 482/574
# Success - Alpha 482: Al2nPXg
# Processing alpha 483/574
# Error in simulation 483: ('Connection aborted.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None))
# Processing alpha 484/574
# Error in simulation 484: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Processing alpha 485/574
# Success - Alpha 485: djPnKLx
# Processing alpha 486/574
# Success - Alpha 486: n7XnvO3
# Processing alpha 487/574
# Success - Alpha 487: vjo5ANQ
# Processing alpha 488/574
# Success - Alpha 488: mjlq0A6
# Processing alpha 489/574
# Success - Alpha 489: xjEeWQn
# Processing alpha 490/574
# Success - Alpha 490: 1w2o0dK
# Processing alpha 491/574
# Success - Alpha 491: zkL5EvO
# Processing alpha 492/574
# Success - Alpha 492: Al2n5AQ
# Processing alpha 493/574
# Success - Alpha 493: J72nJ9n
# Processing alpha 494/574
# Success - Alpha 494: djPnJNE
# Processing alpha 495/574
# Success - Alpha 495: L72nv09
# Processing alpha 496/574
# Success - Alpha 496: R7vNgGz
# Processing alpha 497/574
# Success - Alpha 497: gj0mnLe
# Processing alpha 498/574
# Success - Alpha 498: jjM15Jj
# Processing alpha 499/574
# Success - Alpha 499: V7ROk5A
# Processing alpha 500/574
# Success - Alpha 500: X7O1m75
# Processing alpha 501/574
# Success - Alpha 501: 7j2JAAZ
# Processing alpha 502/574
# Success - Alpha 502: O72oPPq
# Processing alpha 503/574
# Success - Alpha 503: 5l2M01J
# Processing alpha 504/574
# Success - Alpha 504: qjwgq91
# Processing alpha 505/574
# Success - Alpha 505: Gl7kvYG
# Processing alpha 506/574
# Success - Alpha 506: oqkV2nJ
# Processing alpha 507/574
# Success - Alpha 507: oqkVQWm
# Processing alpha 508/574
# Success - Alpha 508: 3l2zYAN
# Processing alpha 509/574
# Success - Alpha 509: jjM1WAZ
# Processing alpha 510/574
# Success - Alpha 510: O72okgb
# Processing alpha 511/574
# Success - Alpha 511: pjp8z3X
# Processing alpha 512/574
# Success - Alpha 512: xjERmbp
# Processing alpha 513/574
# Success - Alpha 513: bjKvoWZ
# Processing alpha 514/574
# Success - Alpha 514: ezWLneN
# Processing alpha 515/574
# Success - Alpha 515: Y79QQjo
# Processing alpha 516/574
# Success - Alpha 516: X7O1KKl
# Processing alpha 517/574
# Success - Alpha 517: 6l2zw1G
# Processing alpha 518/574
# Success - Alpha 518: ljNrlb2
# Processing alpha 519/574
# Success - Alpha 519: Q7oE9PG
# Processing alpha 520/574
# Success - Alpha 520: N72Aboo
# Processing alpha 521/574
# Success - Alpha 521: 6l2zlPG
# Processing alpha 522/574
# Success - Alpha 522: vjodkMA
# Processing alpha 523/574
# Success - Alpha 523: djPdOMX
# Processing alpha 524/574
# Success - Alpha 524: N72AaKL
# Processing alpha 525/574
# Success - Alpha 525: n7X3PPq
# Processing alpha 526/574
# Success - Alpha 526: X7O1RxX
# Processing alpha 527/574
# Success - Alpha 527: 6l2zd1O
# Processing alpha 528/574
# Success - Alpha 528: ezWLadl
# Processing alpha 529/574
# Success - Alpha 529: ezWLaXg
# Processing alpha 530/574
# Success - Alpha 530: N72AKbw
# Processing alpha 531/574
# Success - Alpha 531: 1w2JOpQ
# Processing alpha 532/574
# Success - Alpha 532: 1w2Jlnz
# Processing alpha 533/574
# Success - Alpha 533: O72ozGR
# Processing alpha 534/574
# Success - Alpha 534: R7vdK8b
# Processing alpha 535/574
# Success - Alpha 535: N72A8b7
# Processing alpha 536/574
# Success - Alpha 536: zkLOnrX
# Processing alpha 537/574
# Success - Alpha 537: Gl7kjgG
# Processing alpha 538/574
# Success - Alpha 538: 6l2zWQG
# Processing alpha 539/574
# Error in simulation 539: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Processing alpha 540/574
# Success - Alpha 540: mjlXPwK
# Processing alpha 541/574
# Success - Alpha 541: a7gOkZ6
# Processing alpha 542/574
# Success - Alpha 542: a7gOk0O
# Processing alpha 543/574
# Success - Alpha 543: R7vrM01
# Processing alpha 544/574
# Success - Alpha 544: Al23WJE
# Processing alpha 545/574
# Success - Alpha 545: pjp7rg6
# Processing alpha 546/574
# Success - Alpha 546: 0wa8008
# Processing alpha 547/574
# Success - Alpha 547: Gl7op90
# Processing alpha 548/574
# Success - Alpha 548: Z71oGQ3
# Processing alpha 549/574
# Success - Alpha 549: vjom0Ra
# Processing alpha 550/574
# Success - Alpha 550: oqkYQ1n
# Processing alpha 551/574
# Success - Alpha 551: N72OkK7
# Processing alpha 552/574
# Success - Alpha 552: 1w2gVRJ
# Processing alpha 553/574
# Success - Alpha 553: O729q7d
# Processing alpha 554/574
# Success - Alpha 554: kjYKXv8
# Processing alpha 555/574
# Success - Alpha 555: ezWrqkd
# Processing alpha 556/574
# Success - Alpha 556: ezWrqGJ
# Processing alpha 557/574
# Success - Alpha 557: Q7oQEOW
# Processing alpha 558/574
# Success - Alpha 558: vjommNr
# Processing alpha 559/574
# Success - Alpha 559: V7R8pLA
# Processing alpha 560/574
# Success - Alpha 560: Al23Pzl
# Processing alpha 561/574
# Success - Alpha 561: xjEnddw
# Processing alpha 562/574
# Success - Alpha 562: gj038gK
# Processing alpha 563/574
# Success - Alpha 563: oqkYqKJ
# Processing alpha 564/574
# Success - Alpha 564: V7R86pw
# Processing alpha 565/574
# Success - Alpha 565: bjK9bN6
# Processing alpha 566/574
# Success - Alpha 566: M72x358
# Processing alpha 567/574
# Success - Alpha 567: djPQK9w
# Processing alpha 568/574
# Success - Alpha 568: El2KQ7G
# Processing alpha 569/574
# Success - Alpha 569: oqkYPdv
# Processing alpha 570/574
# Success - Alpha 570: El2K80J
# Processing alpha 571/574
# Success - Alpha 571: 1w2gKYQ
# Processing alpha 572/574
# Success - Alpha 572: O729zgp
# Processing alpha 573/574
# Success - Alpha 573: 5l2velz
# Processing alpha 574/574
# Success - Alpha 574: 1w2g0zz

# %%
# 查看处理进度
def check_progress():
    if os.path.exists('simulation_records.json'):
        with open('simulation_records.json', 'r') as f:
            records = json.load(f)
            total = len(records)
            success = sum(1 for r in records if r['status'] == 'success')
            print(f"Total processed: {total}")
            print(f"Successful: {success}")
            print(f"Failed: {total - success}")
            
# 重新运行失败的simulation
def retry_failed():
    if os.path.exists('simulation_records.json'):
        with open('simulation_records.json', 'r') as f:
            records = json.load(f)
            failed = [r['datafield'] for r in records if r['status'] != 'success']
            print(f"Found {len(failed)} failed simulations to retry")
            return failed
    return []

# %%
def retry_failed_simulations(session):
    """重试失败的模拟"""
    from time import sleep
    
    def load_failed_records(filename='simulation_records.json'):
        """加载失败的记录"""
        if os.path.exists(filename):
            with open(filename, 'r') as f:
                records = json.load(f)
                # 筛选出失败的记录
                failed = [r for r in records if r['status'] != 'success']
                print(f"Found {len(failed)} failed simulations")
                return failed
        return []
    
    failed_records = load_failed_records()
    if not failed_records:
        print("No failed simulations found")
        return
    
    for i, record in enumerate(failed_records, 1):
        datafield = record['datafield']
        print(f"Retrying {i}/{len(failed_records)}: {datafield}")
        
        # 重新构建simulation_data
        simulation_data = {
            'type': 'REGULAR',
            'settings': {
                'instrumentType': 'EQUITY',
                'region': 'USA',
                'universe': 'TOP3000',
                'delay': 1,
                'decay': 0,
                'neutralization': 'SUBINDUSTRY',
                'truncation': 0.08,
                'pasteurization': 'ON',
                'unitHandling': 'VERIFY',
                'nanHandling': 'ON',
                'language': 'FASTEXPR',
                'visualization': False,
            },
            'regular': datafield
        }
        
        try:
            # 发送模拟请求
            sim_resp = session.post(
                'https://api.worldquantbrain.com/simulations',
                json=simulation_data
            )
            
            # 获取进度监控URL
            sim_progress_url = sim_resp.headers['Location']
            
            # 循环检查模拟进度
            while True:
                sim_progress_resp = session.get(sim_progress_url)
                retry_after_sec = float(sim_progress_resp.headers.get("Retry-After", 0))
                
                if retry_after_sec == 0:  # simulation done!
                    break
                    
                sleep(retry_after_sec)
                
            # 获取最终模拟结果
            alpha_id = sim_progress_resp.json()["alpha"]
            print(f"Success - Retry {i}: {alpha_id}")
            
            # 更新记录
            save_simulation_record(
                alpha_id=alpha_id,
                datafield=datafield,
                status='success'
            )
            
        except Exception as e:
            print(f"Error in retry {i}: {e}")
            save_simulation_record(
                alpha_id=None,
                datafield=datafield,
                status=f'retry_failed: {str(e)}'
            )

# %%
# 1. 首先创建新的session
session = get_session()

# 2. 检查失败的模拟数量
def check_failed():
    if os.path.exists('simulation_records.json'):
        with open('simulation_records.json', 'r') as f:
            records = json.load(f)
            failed = [r for r in records if r['status'] != 'success']
            print(f"Total failed simulations: {len(failed)}")
            return failed
    return []

# 3. 重试失败的模拟
retry_failed_simulations(session)

# 4. 再次检查状态
failed = check_failed()
if not failed:
    print("All simulations completed successfully!")
else:
    print(f"Still have {len(failed)} failed simulations")
# Out:
# Found 5 failed simulations
# Retrying 1/5: group_rank(fnd6_dc/cap, subindustry)
# Success - Retry 1: 0waoJ0v
# Retrying 2/5: group_rank(fnd6_newqv1300_tfvaq/cap, subindustry)
# Success - Retry 2: ljNQ6v7
# Retrying 3/5: group_rank(fnd6_pstkl/cap, subindustry)
# Success - Retry 3: 9X29px2
# Retrying 4/5: group_rank(fnd6_pstkrv/cap, subindustry)
# Success - Retry 4: n7XnKQl
# Retrying 5/5: group_rank(fnd6_txw/cap, subindustry)
# Success - Retry 5: zkLOlJE
# Total failed simulations: 5
# Still have 5 failed simulations
